# %%
import pandas as pd

# %%
import requests

url = "https://en.wikipedia.org/wiki/List_of_The_Simpsons_episodes_(seasons_1%E2%80%9320)"

headers = {
    "User-Agent": "Mozilla/5.0"
}

html = requests.get(url, headers=headers).text
tables = pd.read_html(html)

print(len(tables))
tables[1]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_6912\3179324161.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(html)
# 24
#     No. overall  No. in season                                Title  \
# 0             1              1  "Simpsons Roasting on an Open Fire"
# 1             2              2                    "Bart the Genius"
# 2             3              3                    "Homer's Odyssey"
# 3             4              4      "There's No Disgrace Like Home"
# 4             5              5                   "Bart the General"
# 5             6              6                       "Moaning Lisa"
# 6             7              7           "The Call of the Simpsons"
# 7             8              8                  "The Telltale Head"
# 8             9              9              "Life on the Fast Lane"
# ...

# %%
df_25 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2526/E0.csv')

# %%
df_25.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth     4     2   H     1
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle     0     0   D     0
# 2  E0  16/08/2025  15:00     Brighton       Fulham     1     1   D     0
# 3  E0  16/08/2025  15:00   Sunderland     West Ham     3     0   H     0
# 4  E0  16/08/2025  15:00    Tottenham      Burnley     3     0   H     1
#
#    HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# 0     1.76     2.14     1.86
# 1     1.74     2.14     1.86
# ...

# %%
df_25.rename(columns={'FTHG':'HomeGoals', 'FTAG':'AwayGoals'},inplace=True)

# %%
df_25.head()
# Out:
#   Div        Date   Time     HomeTeam     AwayTeam  HomeGoals  AwayGoals FTR  \
# 0  E0  15/08/2025  20:00    Liverpool  Bournemouth          4          2   H
# 1  E0  16/08/2025  12:30  Aston Villa    Newcastle          0          0   D
# 2  E0  16/08/2025  15:00     Brighton       Fulham          1          1   D
# 3  E0  16/08/2025  15:00   Sunderland     West Ham          3          0   H
# 4  E0  16/08/2025  15:00    Tottenham      Burnley          3          0   H
#
#    HTHG  HTAG  ... B365CAHH B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  AvgCAHH  \
# 0     1     0  ...     2.03     1.78   2.07   1.85     2.03     1.88     1.94
# 1     0     0  ...     2.05     1.80   2.02   1.89     2.06     1.80     1.95
# 2     0     0  ...     1.83     2.03   1.93   2.00     1.84     2.03     1.80
# 3     0     0  ...     1.95     1.90   1.97   1.95     1.95     1.94     1.86
# 4     1     0  ...     1.98     1.88   1.99   1.93     1.98     1.91     1.88
#
#    AvgCAHA  BFECAHH  BFECAHA
# ...

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

# %%
url = "https://www.football-data.co.uk/englandm.php"

res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')
links = []

for a in soup.find_all('a',href=True):
    href = a['href']
    if href.endswith('.csv'):
        url = urljoin(url,href)
        links.append(url)

print('Total CSV found: ',len(links))

links
# Out:
# Total CSV found:  153
# ['https://www.football-data.co.uk/mmz4281/2526/E0.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/E1.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/mmz4281/2526/E2.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/E3.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/EC.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2425/E0.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2425/mmz4281/2425/E1.csv',
#  'https://www.football-data.co.uk/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2526/mmz4281/2425/mmz4281/2425/mmz4281/2425/E2.csv',
# ...

# %% [markdown]
# ### FROM PDFS

# %%
pip install "camelot-py[cv]"
# Out:
# ...
#    ---------------------------------------- 0.0/40.1 MB ? eta -:--:--
#    - -------------------------------------- 1.0/40.1 MB 5.2 MB/s eta 0:00:08
#    -- ------------------------------------- 2.1/40.1 MB 5.2 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/40.1 MB 5.1 MB/s eta 0:00:08
#    ---- ----------------------------------- 4.2/40.1 MB 5.1 MB/s eta 0:00:08
#    ----- ---------------------------------- 5.5/40.1 MB 5.2 MB/s eta 0:00:07
#    ------ --------------------------------- 6.6/40.1 MB 5.2 MB/s eta 0:00:07
#    ------- -------------------------------- 7.6/40.1 MB 5.2 MB/s eta 0:00:07
#    -------- ------------------------------- 8.7/40.1 MB 5.2 MB/s eta 0:00:07
#    --------- ------------------------------ 9.7/40.1 MB 5.1 MB/s eta 0:00:06
#    ---------- ----------------------------- 10.7/40.1 MB 5.2 MB/s eta 0:00:06
#    ----------- ---------------------------- 11.8/40.1 MB 5.1 MB/s eta 0:00:06
# ...

# %%
import camelot

# %%
tables = camelot.read_pdf('foo.pdf', pages='1')
tables
# Out:
# <TableList n=1>

# %%
tables.export('foo.csv', f='csv', compress=True)
tables[0].to_csv('foo.csv')
