# %%
import camelot

# %%
tables = camelot.read_pdf('foo.pdf', pages='1', flavor='lattice')
print(tables)
# Out:
# <TableList n=1>

# %%
tables.export('extract.csv', f = 'csv', compress=True)
tables[0].to_csv('extract.csv')
print(tables[0].df)
# Out:
#               0            1                2                     3  \
# 0  Cycle \nName  KI \n(1/km)  Distance \n(mi)  Percent Fuel Savings
# 1                                                  Improved \nSpeed
# 2        2012_2         3.30              1.3                  5.9%
# 3        2145_1         0.68             11.2                  2.4%
# 4        4234_1         0.59             58.7                  8.5%
# 5        2032_2         0.17             57.8                 21.7%
# 6        4171_1         0.07            173.9                 58.1%
#
#                    4                  5                 6
# 0
# 1  Decreased \nAccel  Eliminate \nStops  Decreased \nIdle
# 2               9.5%              29.2%             17.4%
# 3               0.1%               9.5%              2.7%
# 4               1.3%               8.5%              3.3%
# 5               0.3%               2.7%              1.2%
# 6               1.6%               2.1%              0.5%
