# %%
import camelot

# %%
tables = camelot.read_pdf('foo.pdf', pages='1', flavor='lattice')
print(tables)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 tables = camelot.read_pdf('foo.pdf', pages='1', flavor='lattice')
#       2 print(tables)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\camelot\io.py:134, in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     132 p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 134 tables = p.parse(
#     135     flavor=flavor,
#     136     suppress_stdout=suppress_stdout,
#     137     parallel=parallel,
#     138     layout_kwargs=layout_kwargs,
#     139     **kwargs,
#     140 )
#     141 return tables
#
# ...
